# %% [markdown]
# <a href="https://colab.research.google.com/github/Sohan-tough/EthicsAI_Experiments/blob/main/EthicsAI_Exp4_23102A0056.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Sohan Kumar
#
# Roll No.:23102A0056
#
# Exp no.: 4

# %%
# !pip install vaderSentiment transformers torch emoji

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from transformers import pipeline
import emoji

# %%
from transformers import pipeline

sarcasm_model = pipeline(
    "text-classification",
    model="dima806/sarcasm-detection-distilbert"
)

def detect_sarcasm(text):
    return sarcasm_model(text)

# %%
def convert_emojis(text):
    return emoji.demojize(text)

# %%
def detect_sentiment(text):

    score = vader.polarity_scores(text)

    if score['compound'] >= 0.05:
        sentiment = "POSITIVE"

    elif score['compound'] <= -0.05:
        sentiment = "NEGATIVE"

    else:
        sentiment = "NEUTRAL"

    return sentiment, score

# %%
def final_prediction(text):

    text = convert_emojis(text)

    sarcasm = detect_sarcasm(text)

    sentiment, score = detect_sentiment(text)

    # sarcasm correction
    if sarcasm and sentiment == "POSITIVE":
        sentiment = "SARCASTIC (NEGATIVE INTENT)"

    print("Text :", text)
    print("VADER Score :", score)
    print("Sarcasm Detected :", sarcasm)
    print("Final Sentiment :", sentiment)

# %%
final_prediction("I love this phone 😍")
# Out:
# Text : I love this phone :smiling_face_with_heart-eyes:
# VADER Score : {'neg': 0.0, 'neu': 0.488, 'pos': 0.512, 'compound': 0.6369}
# Sarcasm Detected : [{'label': 'No sarcasm', 'score': 0.9110276699066162}]
# Final Sentiment : SARCASTIC (NEGATIVE INTENT)

# %%
final_prediction("Great! My laptop crashed again.")
# Out:
# Text : Great! My laptop crashed again.
# VADER Score : {'neg': 0.0, 'neu': 0.477, 'pos': 0.523, 'compound': 0.6588}
# Sarcasm Detected : [{'label': 'No sarcasm', 'score': 0.8959678411483765}]
# Final Sentiment : SARCASTIC (NEGATIVE INTENT)

# %%
final_prediction("This service is terrible")
# Out:
# Text : This service is terrible
# VADER Score : {'neg': 0.508, 'neu': 0.492, 'pos': 0.0, 'compound': -0.4767}
# Sarcasm Detected : [{'label': 'No sarcasm', 'score': 0.5751006007194519}]
# Final Sentiment : NEGATIVE
